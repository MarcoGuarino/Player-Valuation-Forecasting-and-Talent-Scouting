# %% [markdown]
# # Pre Processing
# **In this file, we will analyze the initial dataset consisting of CSV files in order to create the final dataset. The final dataset, composed of the relevant columns, will be used to train the predictive models**

# %% [markdown]
# Imported libraries

# %%
import pyspark
from pyspark.sql import *
from pyspark.sql.types import *
from pyspark.sql.functions import *
from pyspark import SparkContext, SparkConf
import numpy as np
from pyspark.sql.functions import udf
from pyspark.sql.types import BinaryType
from pyspark.sql import SparkSession
from pyspark.conf import SparkConf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21644\1145623602.py in <module>
# ----> 1 import pyspark
#       2 from pyspark.sql import *
#       3 from pyspark.sql.types import *
#       4 from pyspark.sql.functions import *
#       5 from pyspark import SparkContext, SparkConf
#
# ModuleNotFoundError: No module named 'pyspark'

# %% [markdown]
# Creating the pyspark session

# %%
# Create the session
conf = SparkConf(). \
    set('spark.ui.port', "4050"). \
    set('spark.executor.memory', '15G'). \
    set('spark.driver.memory', '50G'). \
    set('spark.driver.maxResultSize', '40G'). \
    setAppName("PySparkProject"). \
    set('spark.executor.cores', "10"). \
    setMaster("local[*]")

sc = pyspark.SparkContext.getOrCreate(conf=conf)
spark = SparkSession.builder.getOrCreate()

sc._conf.getAll()

# %% [markdown]
# **Work on dataset begins**

# %% [markdown]
# Loading dataframes

# %%
# load the cvs files into dataframes
path = "C:/Users/marco/Desktop"

try:
    df_appearances = spark.read.csv("archive/appearances.csv", header=True, inferSchema=True)
    df_club_games = spark.read.csv("archive/club_games.csv", header=True, inferSchema=True)
    df_clubs = spark.read.csv("archive/clubs.csv", header=True, inferSchema=True)
    df_competitions = spark.read.csv("archive/competitions.csv", header=True, inferSchema=True)
    df_game_events = spark.read.csv("archive/game_events.csv", header=True, inferSchema=True)
    df_games = spark.read.csv("archive/games.csv", header=True, inferSchema=True)
    df_player_valuations = spark.read.csv("archive/player_valuations.csv", header=True, inferSchema=True)
    df_players = spark.read.csv("archive/players.csv", header=True, inferSchema=True)
except Exception:
    df_appearances = spark.read.csv(path+"/archive/appearances.csv", header=True, inferSchema=True)
    df_club_games = spark.read.csv(path+"/archive/club_games.csv", header=True, inferSchema=True)
    df_clubs = spark.read.csv(path+"/archive/clubs.csv", header=True, inferSchema=True)
    df_competitions = spark.read.csv(path+"/archive/competitions.csv", header=True, inferSchema=True)
    df_game_events = spark.read.csv(path+"/archive/game_events.csv", header=True, inferSchema=True)
    df_games = spark.read.csv(path+"/archive/games.csv", header=True, inferSchema=True)
    df_player_valuations = spark.read.csv(path+"/archive/player_valuations.csv", header=True, inferSchema=True)
    df_players = spark.read.csv(path+"/archive/players.csv", header=True, inferSchema=True)

# %%
df_games_join = df_games.join(df_club_games, df_games.game_id == df_club_games.game_id, how='left')
df_appearances_c = df_appearances.withColumnRenamed("date", "datec")
df_appearances_join = df_games.join(df_appearances_c, df_games.game_id == df_appearances_c.game_id, how='left')

# %%
#print(df_games_join.filter((df_games_join.club_id == 31) & (df_games_join.date.between('2020-12-23', '2021-12-23'))).count())
#df_games_join.filter((df_games_join.club_id == 31) & (df_games_join.date.between('2020-12-23', '2021-12-23'))).show()

# %%
#print(df_appearances_join.filter((df_appearances_join.player_id == 148455) & (df_appearances_join.datec.between('2020-12-23', '2021-12-23'))).count())
#df_appearances_join.filter((df_appearances_join.player_id == 148455) & (df_appearances_join.datec.between('2020-12-23', '2021-12-23'))).show()

# %%
# CELLA DA CANCELLARE --> CI SONO DEI DUPLICATI NELLA TABELLA PRESENZE --> NON RISOLVE IL PROBLEMA DI SALAH...  ;(
df_appearances.printSchema()
#conta righe df_appearances
#print(df_appearances.count())
# droppiamo duplicati in base a date e player_id
df_appearances = df_appearances.dropDuplicates(['date', 'player_id'])
#conta righe df_appearances
#print(df_appearances.count())
# Out:
# root
#  |-- appearance_id: string (nullable = true)
#  |-- game_id: integer (nullable = true)
#  |-- player_id: integer (nullable = true)
#  |-- player_club_id: integer (nullable = true)
#  |-- player_current_club_id: integer (nullable = true)
#  |-- date: date (nullable = true)
#  |-- player_name: string (nullable = true)
#  |-- competition_id: string (nullable = true)
#  |-- yellow_cards: integer (nullable = true)
#  |-- red_cards: integer (nullable = true)
#  |-- goals: integer (nullable = true)
#  |-- assists: integer (nullable = true)
#  |-- minutes_played: integer (nullable = true)

# %%
# drop duplicates df_club_games
#df_club_games.printSchema()
#print(df_club_games.count())
df_club_games = df_club_games.dropDuplicates(['club_id', 'own_goals', 'own_position', 'own_manager_name', 'opponent_id', 'opponent_goals', 'opponent_position', 'opponent_manager_name', 'hosting', 'is_win'])
#print(df_club_games.count())

# %%
# drop duplicates df_games
#df_games.printSchema()
#print(df_games.count())
df_games = df_games.dropDuplicates(['home_club_id', 'away_club_id', 'date'])
#print(df_games.count())

# %%
# join players and appearances
df_players_appearances = df_players.join(df_appearances, ["player_id"], how='inner')

# %%
 # join players_appearances and club_games to extract information about the games played by the player
#rinomina player_club_id in club_id
df_players_appearances = df_players_appearances.withColumnRenamed("player_club_id", "club_id")
df_players_appearances = df_players_appearances.join(df_club_games, ["game_id", "club_id"], how='inner')

# %%
# drop useless and duplicated features from df_players_appearances
df_players_appearances = df_players_appearances.drop("current_club_id", "appearance_id",
                                                        "highest_market_value_in_eur", "current_club_name",
                                                        "city_of_birth", "market_value_in_eur",
                                                        "contract_expiration_date", "agent_name",
                                                        "current_club_domestic_competition_id", "image_url",
                                                        "last_season", "url", "player_current_club_id",
                                                        "first_name", "last_name", "player_name", "player_code")

# %%
# drop useless and duplicated features from df_players_valuations
df_player_valuations = df_player_valuations.drop("datetime", "dateweek")

# %%
# rename the column date of df_players_valuations in date_v to avoid confusion with the date of df_players_appearances
df_player_valuations = df_player_valuations.withColumnRenamed("date", "date_v")

# %%
# Join the two dataframes on player_id
df = df_player_valuations.join(df_players_appearances, "player_id")

# %%
# TODO decide if we want to keep the players with no appearances, in case we have to do a union with valuations
# adding before the zeroed column of df_players_appearances

# %%
# we want to keep only the rows where the appearence date is within 1 year from the valuation date
df = df.filter(
    (year(df.date_v) == year(df.date) + 1) & (month(df.date_v) <= month(df.date)) |
    (year(df.date_v) == year(df.date)) & (month(df.date_v) > month(df.date)) |
    (year(df.date_v) == year(df.date)) & (month(df.date_v) == month(df.date)) & (dayofmonth(df.date_v) > dayofmonth(df.date)) |
    (year(df.date_v) == year(df.date) + 1) & (month(df.date_v) == month(df.date)) & (dayofmonth(df.date_v) <= dayofmonth(df.date))
).dropDuplicates(["player_id", "date", "date_v"])

# %%
#df.filter(df.player_id == 148455).show(100)

# %% [markdown]
# We add the statistics of the teams in which the player played during the year and in which the player took the field (appearance)

# %%
# add the is_draw to count the draws
df = df.withColumn("is_draw", when(df.own_goals == df.opponent_goals, 1).otherwise(0))

# add column games_played that counts the instances with key (player_id, date_v)
df = df.withColumn("appearances", count(df.date_v).over(Window.partitionBy("date_v", "player_id")))

# add column games_won that counts the instances with key (player_id, date_v) and is_win = 1
df = df.withColumn("games_won_pl",
                                count(when(df.own_goals > df.opponent_goals, 1)).over(Window.partitionBy("date_v", "player_id")))

# add column games_draw_pl that counts the instances with key (player_id, date_v) and is_draw = 1
df = df.withColumn("games_draw_pl",
                                count(when(df.is_draw == 1, 1)).over(Window.partitionBy("date_v", "player_id")))

df = df.withColumn("games_lost_pl", count(when(df.own_goals < df.opponent_goals, 1)).over(Window.partitionBy("date_v", "player_id")))

# %%
#df.filter(df.player_id == 148455).sort(col("date_v").desc()).show()

# %%
# delete some columns
df = df.drop("game_id", "own_goals", "own_position", "own_manager_name", "opponent_id",
                        "opponent_goals", "opponent_position", "opponent_manager_name", "hosting", "is_win",
                        "is_draw")

# for each (player_id, date_v) add a column with the result of (games_won_pl*3 + games_draw_pl)/games_played
df = df.withColumn("winning_rate_pl",
                                    (df.games_won_pl * 3 + df.games_draw_pl) / df.appearances)

# %%
df.printSchema()

# %%
print(df.count())
df = df.dropDuplicates()
print(df.count())
# Out:
# 2665805
# 2665805

# %%
# Group by the player_id and the valuation date and extract all the important features
df = df.groupBy(
    "player_id", "name", col("market_value_in_eur").alias("market_value"), "date_v",
    col("current_club_id").alias("current_club_id"), col("height_in_cm").alias("height"),
    col("country_of_citizenship").alias("citizenship"), col("date_of_birth").alias("date_birth"), "position",
    "sub_position", "appearances", "games_won_pl", "games_draw_pl", "games_lost_pl", "winning_rate_pl") \
    .agg(collect_set("competition_id").alias("competition_id"),
            collect_set("club_id").alias("club_id"),
            sum("assists").alias("assists"),
            count("date_v").alias("appearances2"),
            sum("goals").alias("goals"),
            sum("minutes_played").alias("minutes_played"),
            sum("red_cards").alias("red_cards"),
            sum("yellow_cards").alias("yellow_cards"))

#df.filter(df.player_id == 148455).show()

# %%
#add last valuation in temporal terms
df = df.withColumn("last_valuation", lag(df.market_value).over(Window.partitionBy("player_id").orderBy("date_v")))

# %% [markdown]
# We add the statistics of the teams in which the player played during the year

# %%
# join club_games and games to extract the date from games
df_club_games_join = df_club_games.join(df_games.select("game_id", "date"), "game_id", how='inner')

# %%
# Expands the player_club_id list into separate columns
df_result_expanded = df.withColumn("club_id", explode(col("club_id")))

# %%
# Peform join based on club_id and apply condition on date
df = df_result_expanded.join(df_club_games_join, ["club_id"]) \
    .where(expr("date <= date_v AND date >= date_v - INTERVAL 1 YEAR"))

# %%
# Select columns
df = df.select(df.columns + df_club_games_join.columns)

# %%
# add column draw that is equal to 1 if own_goals = opponent_goals
df = df.withColumn("is_draw", when(df.own_goals == df.opponent_goals, 1).otherwise(0))

#add column games_played_club that counts the instances with key (player_id, date_v)
df = df.withColumn("games_played_club", count(df.date_v).over(Window.partitionBy("date_v", "player_id")))

# add column games_won_club that counts the instances with key (player_id, date_v) and is_win = 1
df = df.withColumn("games_won_club", count(when(df.own_goals > df.opponent_goals, 1)).over(Window.partitionBy("date_v", "player_id")))

# add column games_draw_club that counts the instances with key (player_id, date_v) and is_draw = 1
df = df.withColumn("games_draw_club", count(when(df.is_draw == 1, 1)).over(Window.partitionBy("date_v", "player_id")))

# add column games_lost_club that counts the instances with key (player_id, date_v) and is_win = 0 and is_draw = 0
df = df.withColumn("games_lost_club", count(when(df.own_goals < df.opponent_goals, 1)).over(Window.partitionBy("date_v", "player_id")))

# %%
df.filter(df.player_id == 148455).show(1000)
# Out:
# +-------+---------+-------------+------------+----------+---------------+------+-----------+----------+--------+------------+-----------+------------+-------------+-------------+------------------+--------------------+-------+------------+-----+--------------+---------+------------+--------------+-------+---------+------------+--------------------+-----------+--------------+-----------------+---------------------+-------+------+----------+-------+-------+---------+------------+--------------------+-----------+--------------+-----------------+---------------------+-------+------+----------+-------+-----------------+--------------+---------------+---------------+
# |club_id|player_id|         name|market_value|    date_v|current_club_id|height|citizenship|date_birth|position|sub_position|appearances|games_won_pl|games_draw_pl|games_lost_pl|   winning_rate_pl|      competition_id|assists|appearances2|goals|minutes_played|red_cards|yellow_cards|last_valuation|game_id|own_goals|own_position|    own_manager_name|opponent_id|opponent_goals|opponent_position|opponent_manager_name|hosting|is_win|      date|game_id|club_id|own_goals|own_position|    own_manager_name|opponent_id|opponent_goals|opponent_position|opponent_manager_name|hosting|is_win|      date|is_draw|games_played_club|games_won_club|games_draw_club|games_lost_club|
# +-------+---------+-------------+------------+----------+---------------+------+-----------+----------+--------+------------+-----------+------------+-------------+-------------+------------------+--------------------+-------+------------+-----+--------------+---------+------------+--------------+-------+---------+------------+--------------------+-----------+--------------+-----------------+---------------------+-------+------+----------+-------+-------+---------+------------+--------------------+-----------+--------------+-----------------+---------------------+-------+------+----------+-------+-----------------+--------------+---------------+---------------+
# |    631|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2486690|        1|           1|       José Mourinho|        281|             1|                2|    Manuel Pellegrini|   Home|     0|2015-01-31|2486690|    631|        1|           1|       José Mourinho|        281|             1|                2|    Manuel Pellegrini|   Home|     0|2015-01-31|      1|              102|            55|             24|             23|
# |    631|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2486500|        4|           1|       José Mourinho|       2288|             2|                3|           Garry Monk|   Home|     1|2014-09-13|2486500|    631|        4|           1|       José Mourinho|       2288|             2|                3|           Garry Monk|   Home|     1|2014-09-13|      0|              102|            55|             24|             23|
# |    631|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2486520|        3|           1|       José Mourinho|        405|             0|                6|         Paul Lambert|   Home|     1|2014-09-27|2486520|    631|        3|           1|       José Mourinho|        405|             0|                6|         Paul Lambert|   Home|     1|2014-09-27|      0|              102|            55|             24|             23|
# |    631|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2486518|        1|           1|       José Mourinho|        281|             1|                6|    Manuel Pellegrini|   Away|     0|2014-09-21|2486518|    631|        1|           1|       José Mourinho|        281|             1|                6|    Manuel Pellegrini|   Away|     0|2014-09-21|      1|              102|            55|             24|             23|
# |    631|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2385041|        1|          -1|       José Mourinho|        141|             1|               -1|      Roberto Mancini|   Away|     0|2014-02-26|2385041|    631|        1|          -1|       José Mourinho|        141|             1|               -1|      Roberto Mancini|   Away|     0|2014-02-26|      1|              102|            55|             24|             23|
# |    631|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2449280|        1|          -1|       José Mourinho|        583|             3|               -1|        Laurent Blanc|   Away|     0|2014-04-02|2449280|    631|        1|          -1|       José Mourinho|        583|             3|               -1|        Laurent Blanc|   Away|     0|2014-04-02|      0|              102|            55|             24|             23|
# |    631|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2495315|        6|          -1|       José Mourinho|        790|             0|               -1|        Ante Simundza|   Home|     1|2014-10-21|2495315|    631|        6|          -1|       José Mourinho|        790|             0|               -1|        Ante Simundza|   Home|     1|2014-10-21|      0|              102|            55|             24|             23|
# |    631|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2385049|        2|          -1|       José Mourinho|        141|             0|               -1|      Roberto Mancini|   Home|     1|2014-03-18|2385049|    631|        2|          -1|       José Mourinho|        141|             0|               -1|      Roberto Mancini|   Home|     1|2014-03-18|      0|              102|            55|             24|             23|
# |    631|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2332262|        2|           3|       José Mourinho|        603|             1|               20| Ole Gunnar Solskjaer|   Away|     1|2014-05-11|2332262|    631|        2|           3|       José Mourinho|        603|             1|               20| Ole Gunnar Solskjaer|   Away|     1|2014-05-11|      0|              102|            55|             24|             23|
# |    631|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2495338|        1|          -1|       José Mourinho|        790|             1|               -1|        Ante Simundza|   Away|     0|2014-11-05|2495338|    631|        1|          -1|       José Mourinho|        790|             1|               -1|        Ante Simundza|   Away|     0|2014-11-05|      1|              102|            55|             24|             23|
# |    631|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2332191|        3|           1|       José Mourinho|        931|             1|               20|         Felix Magath|   Away|     1|2014-03-01|2332191|    631|        3|           1|       José Mourinho|        931|             1|               20|         Felix Magath|   Away|     1|2014-03-01|      0|              102|            55|             24|             23|
# |    631|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2486596|        0|           1|       José Mourinho|        289|             0|               13|        Gustavo Poyet|   Away|     0|2014-11-29|2486596|    631|        0|           1|       José Mourinho|        289|             0|               13|        Gustavo Poyet|   Away|     0|2014-11-29|      1|              102|            55|             24|             23|
# |    631|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2332192|        4|           1|       José Mourinho|        148|             0|                5|         Tim Sherwood|   Home|     1|2014-03-08|2332192|    631|        4|           1|       José Mourinho|        148|             0|                5|         Tim Sherwood|   Home|     1|2014-03-08|      0|              102|            55|             24|             23|
# |    631|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2486636|        2|           1|       José Mourinho|        512|             0|               13|          Mark Hughes|   Away|     1|2014-12-22|2486636|    631|        2|           1|       José Mourinho|        512|             0|               13|          Mark Hughes|   Away|     1|2014-12-22|      0|              102|            55|             24|             23|
# |    631|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2332143|        6|           2|       José Mourinho|         11|             0|                4|        Arsène Wenger|   Home|     1|2014-03-22|2332143|    631|        6|           2|       José Mourinho|         11|             0|                4|        Arsène Wenger|   Home|     1|2014-03-22|      0|              102|            55|             24|             23|
# |    631|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2528144|        2|          -1|       José Mourinho|       1027|             4|               -1|       Phil Parkinson|   Home|     0|2015-01-24|2528144|    631|        2|          -1|       José Mourinho|       1027|             4|               -1|       Phil Parkinson|   Home|     0|2015-01-24|      0|              102|            55|             24|             23|
# |    631|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2486606|        3|           1|       José Mourinho|        148|             0|               10|  Mauricio Pochettino|   Home|     1|2014-12-03|2486606|    631|        3|           1|       José Mourinho|        148|             0|               10|  Mauricio Pochettino|   Home|     1|2014-12-03|      0|              102|            55|             24|             23|
# |    631|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2486716|        1|           1|       José Mourinho|         29|             0|               12|     Roberto Martínez|   Home|     1|2015-02-11|2486716|    631|        1|           1|       José Mourinho|         29|             0|               12|     Roberto Martínez|   Home|     1|2015-02-11|      0|              102|            55|             24|             23|
# |    631|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2332154|        0|           3|       José Mourinho|        873|             1|               13|           Tony Pulis|   Away|     0|2014-03-29|2332154|    631|        0|           3|       José Mourinho|        873|             1|               13|           Tony Pulis|   Away|     0|2014-03-29|      0|              102|            55|             24|             23|
# |    631|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2486613|        1|           1|       José Mourinho|        762|             2|                7|          Alan Pardew|   Away|     0|2014-12-06|2486613|    631|        1|           1|       José Mourinho|        762|             2|                7|          Alan Pardew|   Away|     0|2014-12-06|      0|              102|            55|             24|             23|
# |    631|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2486542|        2|           1|       José Mourinho|        873|             1|               16|         Neil Warnock|   Away|     1|2014-10-18|2486542|    631|        2|           1|       José Mourinho|        873|             1|               16|         Neil Warnock|   Away|     1|2014-10-18|      0|              102|            55|             24|             23|
# |    631|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2486655|        1|           1|       José Mourinho|        180|             1|                4|        Ronald Koeman|   Away|     0|2014-12-28|2486655|    631|        1|           1|       José Mourinho|        180|             1|                4|        Ronald Koeman|   Away|     0|2014-12-28|      1|              102|            55|             24|             23|
# |    631|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2332278|        1|           2|       José Mourinho|       2288|             0|               15|           Garry Monk|   Away|     1|2014-04-13|2332278|    631|        1|           2|       José Mourinho|       2288|             0|               15|           Garry Monk|   Away|     1|2014-04-13|      0|              102|            55|             24|             23|
# |    631|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2495298|        1|          -1|       José Mourinho|        336|             0|               -1|          Marco Silva|   Away|     1|2014-09-30|2495298|    631|        1|          -1|       José Mourinho|        336|             0|               -1|          Marco Silva|   Away|     1|2014-09-30|      0|              102|            55|             24|             23|
# |    631|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2495371|        3|          -1|       José Mourinho|        336|             1|               -1|          Marco Silva|   Home|     1|2014-12-10|2495371|    631|        3|          -1|       José Mourinho|        336|             1|               -1|          Marco Silva|   Home|     1|2014-12-10|      0|              102|            55|             24|             23|
# |    631|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2517340|        3|          -1|       José Mourinho|       1010|             0|               -1|    Slavisa Jokanovic|   Home|     1|2015-01-04|2517340|    631|        3|          -1|       José Mourinho|       1010|             0|               -1|    Slavisa Jokanovic|   Home|     1|2015-01-04|      0|              102|            55|             24|             23|
# |    631|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2478480|        2|           3|       José Mourinho|       1003|             0|               16|        Nigel Pearson|   Home|     1|2014-08-23|2478480|    631|        2|           3|       José Mourinho|       1003|             0|               16|        Nigel Pearson|   Home|     1|2014-08-23|      0|              102|            55|             24|             23|
# |    631|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2452863|        0|          -1|       José Mourinho|         13|             0|               -1|        Diego Simeone|   Away|     0|2014-04-22|2452863|    631|        0|          -1|       José Mourinho|         13|             0|               -1|        Diego Simeone|   Away|     0|2014-04-22|      1|              102|            55|             24|             23|
# |    631|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2486667|        3|           2|       José Mourinho|        148|             5|                5|  Mauricio Pochettino|   Away|     0|2015-01-01|2486667|    631|        3|           2|       José Mourinho|        148|             5|                5|  Mauricio Pochettino|   Away|     0|2015-01-01|      0|              102|            55|             24|             23|
# |    631|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2332137|        0|           2|       José Mourinho|        405|             1|               11|         Paul Lambert|   Away|     0|2014-03-15|2332137|    631|        0|           2|       José Mourinho|        405|             1|               11|         Paul Lambert|   Away|     0|2014-03-15|      0|              102|            55|             24|             23|
# |    631|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2486686|        5|           1|       José Mourinho|       2288|             0|                9|           Garry Monk|   Away|     1|2015-01-17|2486686|    631|        5|           1|       José Mourinho|       2288|             0|                9|           Garry Monk|   Away|     1|2015-01-17|      0|              102|            55|             24|             23|
# |    631|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2490854|        1|          -1|       José Mourinho|         33|             1|               -1|          Jens Keller|   Home|     0|2014-09-17|2490854|    631|        1|          -1|       José Mourinho|         33|             1|               -1|          Jens Keller|   Home|     0|2014-09-17|      1|              102|            55|             24|             23|
# |    631|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2332161|        1|           1|       José Mourinho|         29|             0|                7|     Roberto Martínez|   Home|     1|2014-02-22|2332161|    631|        1|           1|       José Mourinho|         29|             0|                7|     Roberto Martínez|   Home|     1|2014-02-22|      0|              102|            55|             24|             23|
# |    631|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2332256|        0|           3|       José Mourinho|       1123|             0|               18|           Neil Adams|   Home|     0|2014-05-04|2332256|    631|        0|           3|       José Mourinho|       1123|             0|               18|           Neil Adams|   Home|     0|2014-05-04|      1|              102|            55|             24|             23|
# |    631|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2452865|        1|          -1|       José Mourinho|         13|             3|               -1|        Diego Simeone|   Home|     0|2014-04-30|2452865|    631|        1|          -1|       José Mourinho|         13|             3|               -1|        Diego Simeone|   Home|     0|2014-04-30|      0|              102|            55|             24|             23|
# |    631|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2486699|        2|           1|       José Mourinho|        405|             1|               16|         Paul Lambert|   Away|     1|2015-02-07|2486699|    631|        2|           1|       José Mourinho|        405|             1|               16|         Paul Lambert|   Away|     1|2015-02-07|      0|              102|            55|             24|             23|
# |    631|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2486579|        2|           1|       José Mourinho|        984|             0|               13|          Alan Irvine|   Home|     1|2014-11-22|2486579|    631|        2|           1|       José Mourinho|        984|             0|               13|          Alan Irvine|   Home|     1|2014-11-22|      0|              102|            55|             24|             23|
# |    631|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2332268|        3|           3|       José Mourinho|        512|             0|               10|          Mark Hughes|   Home|     1|2014-04-05|2332268|    631|        3|           3|       José Mourinho|        512|             0|               10|          Mark Hughes|   Home|     1|2014-04-05|      0|              102|            55|             24|             23|
# |    631|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2486641|        2|           1|       José Mourinho|        379|             0|                5|        Sam Allardyce|   Home|     1|2014-12-26|2486641|    631|        2|           1|       José Mourinho|        379|             0|                5|        Sam Allardyce|   Home|     1|2014-12-26|      0|              102|            55|             24|             23|
# |    631|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2486537|        2|           1|       José Mourinho|         11|             0|                8|        Arsène Wenger|   Home|     1|2014-10-05|2486537|    631|        2|           1|       José Mourinho|         11|             0|                8|        Arsène Wenger|   Home|     1|2014-10-05|      0|              102|            55|             24|             23|
# |    631|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2423908|        0|          -1|       José Mourinho|        281|             2|               -1|    Manuel Pellegrini|   Away|     0|2014-02-15|2423908|    631|        0|          -1|       José Mourinho|        281|             2|               -1|    Manuel Pellegrini|   Away|     0|2014-02-15|      0|              102|            55|             24|             23|
# |    631|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2486496|        6|           1|       José Mourinho|         29|             3|               17|     Roberto Martínez|   Away|     1|2014-08-30|2486496|    631|        6|           1|       José Mourinho|         29|             3|               17|     Roberto Martínez|   Away|     1|2014-08-30|      0|              102|            55|             24|             23|
# |    631|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2495347|        5|          -1|       José Mourinho|         33|             0|               -1|    Roberto Di Matteo|   Away|     1|2014-11-25|2495347|    631|        5|          -1|       José Mourinho|         33|             0|               -1|    Roberto Di Matteo|   Away|     1|2014-11-25|      0|              102|            55|             24|             23|
# |    631|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2460297|        3|           1|       José Mourinho|       1132|             1|               19|           Sean Dyche|   Away|     1|2014-08-18|2460297|    631|        3|           1|       José Mourinho|       1132|             1|               19|           Sean Dyche|   Away|     1|2014-08-18|      0|              102|            55|             24|             23|
# |    631|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2486557|        1|           1|       José Mourinho|        985|             1|                8|       Louis van Gaal|   Away|     0|2014-10-26|2486557|    631|        1|           1|       José Mourinho|        985|             1|                8|       Louis van Gaal|   Away|     0|2014-10-26|      1|              102|            55|             24|             23|
# |    631|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2486671|        2|           1|       José Mourinho|        762|             0|               10|          John Carver|   Home|     1|2015-01-10|2486671|    631|        2|           1|       José Mourinho|        762|             0|               10|          John Carver|   Home|     1|2015-01-10|      0|              102|            55|             24|             23|
# |    631|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2486561|        2|           1|       José Mourinho|       1039|             1|               19|       Harry Redknapp|   Home|     1|2014-11-01|2486561|    631|        2|           1|       José Mourinho|       1039|             1|               19|       Harry Redknapp|   Home|     1|2014-11-01|      0|              102|            55|             24|             23|
# |    631|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2332295|        1|           3|       José Mourinho|        289|             2|               17|        Gustavo Poyet|   Home|     0|2014-04-19|2332295|    631|        1|           3|       José Mourinho|        289|             2|               17|        Gustavo Poyet|   Home|     0|2014-04-19|      0|              102|            55|             24|             23|
# |    631|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2486621|        2|           1|       José Mourinho|       3008|             0|               19|          Steve Bruce|   Home|     1|2014-12-13|2486621|    631|        2|           1|       José Mourinho|       3008|             0|               19|          Steve Bruce|   Home|     1|2014-12-13|      0|              102|            55|             24|             23|
# |    631|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2449284|        2|          -1|       José Mourinho|        583|             0|               -1|        Laurent Blanc|   Home|     1|2014-04-08|2449284|    631|        2|          -1|       José Mourinho|        583|             0|               -1|        Laurent Blanc|   Home|     1|2014-04-08|      0|              102|            55|             24|             23|
# |    631|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2332251|        2|           3|       José Mourinho|         31|             0|                2|      Brendan Rodgers|   Away|     1|2014-04-27|2332251|    631|        2|           3|       José Mourinho|         31|             0|                2|      Brendan Rodgers|   Away|     1|2014-04-27|      0|              102|            55|             24|             23|
# |    631|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2486569|        2|           1|       José Mourinho|         31|             1|               11|      Brendan Rodgers|   Away|     1|2014-11-08|2486569|    631|        2|           1|       José Mourinho|         31|             1|               11|      Brendan Rodgers|   Away|     1|2014-11-08|      0|              102|            55|             24|             23|
# |    430|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2478760|        4|           7|   Vincenzo Montella|        458|             3|               10|     Giuseppe Iachini|   Home|     1|2015-01-11|2478760|    430|        4|           7|   Vincenzo Montella|        458|             3|               10|     Giuseppe Iachini|   Home|     1|2015-01-11|      0|              102|            55|             24|             23|
# |    430|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2492420|        3|          -1|   Vincenzo Montella|        855|             0|               -1|   Jocelyn Gourvennec|   Home|     1|2014-09-18|2492420|    430|        3|          -1|   Vincenzo Montella|        855|             0|               -1|   Jocelyn Gourvennec|   Home|     1|2014-09-18|      0|              102|            55|             24|             23|
# |    430|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2492426|        1|          -1|   Vincenzo Montella|       1091|             1|               -1| Angelos Anastasiadis|   Home|     0|2014-11-06|2492426|    430|        1|          -1|   Vincenzo Montella|       1091|             1|               -1| Angelos Anastasiadis|   Home|     0|2014-11-06|      1|              102|            55|             24|             23|
# |    430|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2385106|        1|          -1|   Vincenzo Montella|       3426|             1|               -1|    Niels Frederiksen|   Home|     0|2014-02-27|2385106|    430|        1|          -1|   Vincenzo Montella|       3426|             1|               -1|    Niels Frederiksen|   Home|     0|2014-02-27|      1|              102|            55|             24|             23|
# |    430|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2478639|        3|           9|   Vincenzo Montella|         46|             0|               10|      Walter Mazzarri|   Home|     1|2014-10-05|2478639|    430|        3|           9|   Vincenzo Montella|         46|             0|               10|      Walter Mazzarri|   Home|     1|2014-10-05|      0|              102|            55|             24|             23|
# |    430|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2359499|        0|           4|   Vincenzo Montella|          5|             2|               12|     Clarence Seedorf|   Home|     0|2014-03-26|2359499|    430|        0|           4|   Vincenzo Montella|          5|             2|               12|     Clarence Seedorf|   Home|     0|2014-03-26|      0|              102|            55|             24|             23|
# |    430|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2359547|        3|           4|   Vincenzo Montella|       1025|             0|               17|    Davide Ballardini|   Away|     1|2014-04-26|2359547|    430|        3|           4|   Vincenzo Montella|       1025|             0|               17|    Davide Ballardini|   Away|     1|2014-04-26|      0|              102|            55|             24|             23|
# |    430|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2359567|        1|           4|   Vincenzo Montella|       1210|             0|               20|        Davide Nicola|   Away|     1|2014-05-11|2359567|    430|        1|           4|   Vincenzo Montella|       1210|             0|               20|        Davide Nicola|   Away|     1|2014-05-11|      0|              102|            55|             24|             23|
# |    430|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2478670|        3|          10|   Vincenzo Montella|        410|             0|                5|  Andrea Stramaccioni|   Home|     1|2014-10-29|2478670|    430|        3|          10|   Vincenzo Montella|        410|             0|                5|  Andrea Stramaccioni|   Home|     1|2014-10-29|      0|              102|            55|             24|             23|
# |    430|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2359541|        0|           4|   Vincenzo Montella|         12|             1|                2|          Rudi Garcia|   Home|     0|2014-04-19|2359541|    430|        0|           4|   Vincenzo Montella|         12|             1|                2|          Rudi Garcia|   Home|     0|2014-04-19|      0|              102|            55|             24|             23|
# |    430|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2478691|        0|          11|   Vincenzo Montella|       6195|             1|                3|       Rafael Benítez|   Home|     0|2014-11-09|2478691|    430|        0|          11|   Vincenzo Montella|       6195|             1|                3|       Rafael Benítez|   Home|     0|2014-11-09|      0|              102|            55|             24|             23|
# |    430|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2359467|        0|           4|   Vincenzo Montella|        506|             1|                1|        Antonio Conte|   Away|     0|2014-03-09|2359467|    430|        0|           4|   Vincenzo Montella|        506|             1|                1|        Antonio Conte|   Away|     0|2014-03-09|      0|              102|            55|             24|             23|
# |    430|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2478708|        4|           8|   Vincenzo Montella|       1390|             0|               17|         Zdenek Zeman|   Away|     1|2014-11-30|2478708|    430|        4|           8|   Vincenzo Montella|       1390|             0|               17|         Zdenek Zeman|   Away|     1|2014-11-30|      0|              102|            55|             24|             23|
# |    430|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2359487|        1|           4|   Vincenzo Montella|       6195|             0|                3|       Rafael Benítez|   Away|     1|2014-03-23|2359487|    430|        1|           4|   Vincenzo Montella|       6195|             0|                3|       Rafael Benítez|   Away|     1|2014-03-23|      0|              102|            55|             24|             23|
# |    430|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2478756|        0|           9|   Vincenzo Montella|        130|             1|               20|     Roberto Donadoni|   Away|     0|2015-01-06|2478756|    430|        0|           9|   Vincenzo Montella|        130|             1|               20|     Roberto Donadoni|   Away|     0|2015-01-06|      0|              102|            55|             24|             23|
# |    430|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|2437609|        0|          -1|   Vincenzo Montella|        506|             1|               -1|        Antonio Conte|   Home|     0|2014-03-20|2437609|    430|        0|          -1|   Vincenzo Montella|        506|             1|               -1|        Antonio Conte|   Home|     0|2014-03-20|      0|              102|            55|             24|             23|
# ...
# |     31|   148455|Mohamed Salah|    40000000|2017-10-23|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         46|          29|            9|            8|2.0869565217391304|[CL, CIT, EL, IT1...|     13|          46|   24|          3565|        0|           2|      35000000|2698231|        3|           2|        Jürgen Klopp|        641|             0|               17|        Aitor Karanka|   Away|     1|2016-12-14|2698231|     31|        3|           2|        Jürgen Klopp|        641|             0|               17|        Aitor Karanka|   Away|     1|2016-12-14|      0|               98|            60|             20|             18|
# |     12|   148455|Mohamed Salah|    80000000|2018-01-02|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         49|          31|           12|            6| 2.142857142857143|[CL, CIT, EL, IT1...|     14|          49|   33|          3831|        0|           0|      40000000|2816672|        2|          -1|   Luciano Spalletti|       1429|             1|               -1|      Andrea Camplone|   Home|     1|2017-02-01|2816672|     12|        2|          -1|   Luciano Spalletti|       1429|             1|               -1|      Andrea Camplone|   Home|     1|2017-02-01|      0|              105|            63|             24|             18|
# |     12|   148455|Mohamed Salah|    80000000|2018-01-02|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         49|          31|           12|            6| 2.142857142857143|[CL, CIT, EL, IT1...|     14|          49|   33|          3831|        0|           0|      40000000|2897463|        1|           4|Eusebio Di Francesco|       1390|             0|               15|          Diego López|   Home|     1|2017-12-16|2897463|     12|        1|           4|Eusebio Di Francesco|       1390|             0|               15|          Diego López|   Home|     1|2017-12-16|      0|              105|            63|             24|             18|
# |     12|   148455|Mohamed Salah|    80000000|2018-01-02|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         49|          31|           12|            6| 2.142857142857143|[CL, CIT, EL, IT1...|     14|          49|   33|          3831|        0|           0|      40000000|2831541|        2|          -1|   Luciano Spalletti|       1041|             1|               -1|        Bruno Génésio|   Home|     1|2017-03-16|2831541|     12|        2|          -1|   Luciano Spalletti|       1041|             1|               -1|        Bruno Génésio|   Home|     1|2017-03-16|      0|              105|            63|             24|             18|
# |     12|   148455|Mohamed Salah|    80000000|2018-01-02|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         49|          31|           12|            6| 2.142857142857143|[CL, CIT, EL, IT1...|     14|          49|   33|          3831|        0|           0|      40000000|2897263|        1|           5|Eusebio Di Francesco|       1025|             0|               12|     Roberto Donadoni|   Home|     1|2017-10-28|2897263|     12|        1|           5|Eusebio Di Francesco|       1025|             0|               12|     Roberto Donadoni|   Home|     1|2017-10-28|      0|              105|            63|             24|             18|
# |     12|   148455|Mohamed Salah|    80000000|2018-01-02|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         49|          31|           12|            6| 2.142857142857143|[CL, CIT, EL, IT1...|     14|          49|   33|          3831|        0|           0|      40000000|2726767|        2|           2|   Luciano Spalletti|        749|             0|               17| Giovanni Martusci...|   Home|     1|2017-04-01|2726767|     12|        2|           2|   Luciano Spalletti|        749|             0|               17| Giovanni Martusci...|   Home|     1|2017-04-01|      0|              105|            63|             24|             18|
# |     12|   148455|Mohamed Salah|    80000000|2018-01-02|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         49|          31|           12|            6| 2.142857142857143|[CL, CIT, EL, IT1...|     14|          49|   33|          3831|        0|           0|      40000000|2726749|        3|           2|   Luciano Spalletti|        458|             0|               18|          Diego López|   Away|     1|2017-03-12|2726749|     12|        3|           2|   Luciano Spalletti|        458|             0|               18|          Diego López|   Away|     1|2017-03-12|      0|              105|            63|             24|             18|
# |     12|   148455|Mohamed Salah|    80000000|2018-01-02|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         49|          31|           12|            6| 2.142857142857143|[CL, CIT, EL, IT1...|     14|          49|   33|          3831|        0|           0|      40000000|2897158|        1|           7|Eusebio Di Francesco|        800|             0|               16| Gian Piero Gasperini|   Away|     1|2017-08-20|2897158|     12|        1|           7|Eusebio Di Francesco|        800|             0|               16| Gian Piero Gasperini|   Away|     1|2017-08-20|      0|              105|            63|             24|             18|
# |     12|   148455|Mohamed Salah|    80000000|2018-01-02|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         49|          31|           12|            6| 2.142857142857143|[CL, CIT, EL, IT1...|     14|          49|   33|          3831|        0|           0|      40000000|2805658|        4|          -1|   Luciano Spalletti|       1050|             0|               -1|         Fran Escribá|   Away|     1|2017-02-16|2805658|     12|        4|          -1|   Luciano Spalletti|       1050|             0|               -1|         Fran Escribá|   Away|     1|2017-02-16|      0|              105|            63|             24|             18|
# |     12|   148455|Mohamed Salah|    80000000|2018-01-02|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         49|          31|           12|            6| 2.142857142857143|[CL, CIT, EL, IT1...|     14|          49|   33|          3831|        0|           0|      40000000|2897223|        2|           5|Eusebio Di Francesco|          5|             0|                8|    Vincenzo Montella|   Away|     1|2017-10-01|2897223|     12|        2|           5|Eusebio Di Francesco|          5|             0|                8|    Vincenzo Montella|   Away|     1|2017-10-01|      0|              105|            63|             24|             18|
# |     12|   148455|Mohamed Salah|    80000000|2018-01-02|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         49|          31|           12|            6| 2.142857142857143|[CL, CIT, EL, IT1...|     14|          49|   33|          3831|        0|           0|      40000000|2897199|        4|           6|Eusebio Di Francesco|       4171|             0|               20|         Marco Baroni|   Away|     1|2017-09-20|2897199|     12|        4|           6|Eusebio Di Francesco|       4171|             0|               20|         Marco Baroni|   Away|     1|2017-09-20|      0|              105|            63|             24|             18|
# |     12|   148455|Mohamed Salah|    80000000|2018-01-02|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         49|          31|           12|            6| 2.142857142857143|[CL, CIT, EL, IT1...|     14|          49|   33|          3831|        0|           0|      40000000|2726695|        4|           2|   Luciano Spalletti|        430|             0|                8|          Paulo Sousa|   Home|     1|2017-02-07|2726695|     12|        4|           2|   Luciano Spalletti|        430|             0|                8|          Paulo Sousa|   Home|     1|2017-02-07|      0|              105|            63|             24|             18|
# |     12|   148455|Mohamed Salah|    80000000|2018-01-02|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         49|          31|           12|            6| 2.142857142857143|[CL, CIT, EL, IT1...|     14|          49|   33|          3831|        0|           0|      40000000|2897483|        1|           4|Eusebio Di Francesco|       6574|             1|               14|     Giuseppe Iachini|   Home|     0|2017-12-30|2897483|     12|        1|           4|Eusebio Di Francesco|       6574|             1|               14|     Giuseppe Iachini|   Home|     0|2017-12-30|      1|              105|            63|             24|             18|
# |     12|   148455|Mohamed Salah|    80000000|2018-01-02|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         49|          31|           12|            6| 2.142857142857143|[CL, CIT, EL, IT1...|     14|          49|   33|          3831|        0|           0|      40000000|2897469|        0|           4|Eusebio Di Francesco|        506|             1|                2| Massimiliano Allegri|   Away|     0|2017-12-23|2897469|     12|        0|           4|Eusebio Di Francesco|        506|             1|                2| Massimiliano Allegri|   Away|     0|2017-12-23|      0|              105|            63|             24|             18|
# |     12|   148455|Mohamed Salah|    80000000|2018-01-02|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         49|          31|           12|            6| 2.142857142857143|[CL, CIT, EL, IT1...|     14|          49|   33|          3831|        0|           0|      40000000|2897559|        1|           4|Eusebio Di Francesco|        252|             1|               18|    Davide Ballardini|   Away|     0|2017-11-26|2897559|     12|        1|           4|Eusebio Di Francesco|        252|             1|               18|    Davide Ballardini|   Away|     0|2017-11-26|      1|              105|            63|             24|             18|
# |     12|   148455|Mohamed Salah|    80000000|2018-01-02|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         49|          31|           12|            6| 2.142857142857143|[CL, CIT, EL, IT1...|     14|          49|   33|          3831|        0|           0|      40000000|2726722|        4|           2|   Luciano Spalletti|        416|             1|                9|    Siniša Mihajlović|   Home|     1|2017-02-19|2726722|     12|        4|           2|   Luciano Spalletti|        416|             1|                9|    Siniša Mihajlović|   Home|     1|2017-02-19|      0|              105|            63|             24|             18|
# |     12|   148455|Mohamed Salah|    80000000|2018-01-02|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         49|          31|           12|            6| 2.142857142857143|[CL, CIT, EL, IT1...|     14|          49|   33|          3831|        0|           0|      40000000|2726762|        3|           2|   Luciano Spalletti|       6574|             1|               15| Eusebio Di Francesco|   Home|     1|2017-03-19|2726762|     12|        3|           2|   Luciano Spalletti|       6574|             1|               15| Eusebio Di Francesco|   Home|     1|2017-03-19|      0|              105|            63|             24|             18|
# |     12|   148455|Mohamed Salah|    80000000|2018-01-02|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         49|          31|           12|            6| 2.142857142857143|[CL, CIT, EL, IT1...|     14|          49|   33|          3831|        0|           0|      40000000|2917362|        0|          -1|Eusebio Di Francesco|         13|             0|               -1|        Diego Simeone|   Home|     0|2017-09-12|2917362|     12|        0|          -1|Eusebio Di Francesco|         13|             0|               -1|        Diego Simeone|   Home|     0|2017-09-12|      1|              105|            63|             24|             18|
# |     12|   148455|Mohamed Salah|    80000000|2018-01-02|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         49|          31|           12|            6| 2.142857142857143|[CL, CIT, EL, IT1...|     14|          49|   33|          3831|        0|           0|      40000000|2820742|        3|          -1|   Luciano Spalletti|        398|             2|               -1|       Simone Inzaghi|   Home|     1|2017-04-04|2820742|     12|        3|          -1|   Luciano Spalletti|        398|             2|               -1|       Simone Inzaghi|   Home|     1|2017-04-04|      0|              105|            63|             24|             18|
# |     12|   148455|Mohamed Salah|    80000000|2018-01-02|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         49|          31|           12|            6| 2.142857142857143|[CL, CIT, EL, IT1...|     14|          49|   33|          3831|        0|           0|      40000000|2726672|        1|           2|   Luciano Spalletti|        410|             0|               11|        Luigi Delneri|   Away|     1|2017-01-15|2726672|     12|        1|           2|   Luciano Spalletti|        410|             0|               11|        Luigi Delneri|   Away|     1|2017-01-15|      0|              105|            63|             24|             18|
# |     12|   148455|Mohamed Salah|    80000000|2018-01-02|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         49|          31|           12|            6| 2.142857142857143|[CL, CIT, EL, IT1...|     14|          49|   33|          3831|        0|           0|      40000000|2820741|        0|          -1|   Luciano Spalletti|        398|             2|               -1|       Simone Inzaghi|   Away|     0|2017-03-01|2820741|     12|        0|          -1|   Luciano Spalletti|        398|             2|               -1|       Simone Inzaghi|   Away|     0|2017-03-01|      0|              105|            63|             24|             18|
# |     12|   148455|Mohamed Salah|    80000000|2018-01-02|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         49|          31|           12|            6| 2.142857142857143|[CL, CIT, EL, IT1...|     14|          49|   33|          3831|        0|           0|      40000000|2726729|        3|           2|   Luciano Spalletti|         46|             1|                6|        Stefano Pioli|   Away|     1|2017-02-26|2726729|     12|        3|           2|   Luciano Spalletti|         46|             1|                6|        Stefano Pioli|   Away|     1|2017-02-26|      0|              105|            63|             24|             18|
# +-------+---------+-------------+------------+----------+---------------+------+-----------+----------+--------+------------+-----------+------------+-------------+-------------+------------------+--------------------+-------+------------+-----+--------------+---------+------------+--------------+-------+---------+------------+--------------------+-----------+--------------+-----------------+---------------------+-------+------+----------+-------+-------+---------+------------+--------------------+-----------+--------------+-----------------+---------------------+-------+------+----------+-------+-----------------+--------------+---------------+---------------+
# only showing top 1000 rows

# %%
#delete some columns
df = df.drop("game_id", "own_goals",  "own_position", "own_manager_name", "opponent_id", "opponent_goals", "opponent_position", "opponent_manager_name", "hosting", "is_win", "date", "is_draw")

# %%
#df = df.dropDuplicates(["player_id", "date_v"])
df = df.dropDuplicates()

# %%
# for each (player_id, date_v) add a column with the result of (games_won_club*3 + games_draw_club)/games_played_club
df = df.withColumn("winning_rate_club", (df.games_won_club*3 + df.games_draw_club)/df.games_played_club)

# %%
df.filter(df.player_id == 148455).show(50)
# Out:
# +-------+---------+-------------+------------+----------+---------------+------+-----------+----------+--------+------------+-----------+------------+-------------+-------------+------------------+--------------------+-------+------------+-----+--------------+---------+------------+--------------+-------+-----------------+--------------+---------------+---------------+------------------+
# |club_id|player_id|         name|market_value|    date_v|current_club_id|height|citizenship|date_birth|position|sub_position|appearances|games_won_pl|games_draw_pl|games_lost_pl|   winning_rate_pl|      competition_id|assists|appearances2|goals|minutes_played|red_cards|yellow_cards|last_valuation|club_id|games_played_club|games_won_club|games_draw_club|games_lost_club| winning_rate_club|
# +-------+---------+-------------+------------+----------+---------------+------+-----------+----------+--------+------------+-----------+------------+-------------+-------------+------------------+--------------------+-------+------------+-----+--------------+---------+------------+--------------+-------+-----------------+--------------+---------------+---------------+------------------+
# |    631|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|    631|              102|            55|             24|             23|1.8529411764705883|
# |    430|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|    430|              102|            55|             24|             23|1.8529411764705883|
# |    631|   148455|Mohamed Salah|    12000000|2015-03-20|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         16|          10|            3|            3|            2.0625|[CL, FAC, CIT, EL...|      3|          16|    6|           879|        0|           1|      10000000|    631|              102|            56|             27|             19| 1.911764705882353|
# |    430|   148455|Mohamed Salah|    12000000|2015-03-20|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         16|          10|            3|            3|            2.0625|[CL, FAC, CIT, EL...|      3|          16|    6|           879|        0|           1|      10000000|    430|              102|            56|             27|             19| 1.911764705882353|
# |    631|   148455|Mohamed Salah|    18000000|2015-07-01|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         32|          17|            5|           10|              1.75|[CL, FAC, CIT, EL...|      5|          32|    9|          1970|        0|           1|      12000000|    631|              104|            59|             27|             18|1.9615384615384615|
# |    430|   148455|Mohamed Salah|    18000000|2015-07-01|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         32|          17|            5|           10|              1.75|[CL, FAC, CIT, EL...|      5|          32|    9|          1970|        0|           1|      12000000|    430|              104|            59|             27|             18|1.9615384615384615|
# |     12|   148455|Mohamed Salah|    20000000|2015-11-05|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         43|          21|            9|           13|1.6744186046511629|[CL, FAC, CIT, EL...|      5|          43|   15|          3055|        0|           3|      18000000|     12|              161|            80|             42|             39|1.7515527950310559|
# |    631|   148455|Mohamed Salah|    20000000|2015-11-05|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         43|          21|            9|           13|1.6744186046511629|[CL, FAC, CIT, EL...|      5|          43|   15|          3055|        0|           3|      18000000|    631|              161|            80|             42|             39|1.7515527950310559|
# |    430|   148455|Mohamed Salah|    20000000|2015-11-05|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         43|          21|            9|           13|1.6744186046511629|[CL, FAC, CIT, EL...|      5|          43|   15|          3055|        0|           3|      18000000|    430|              161|            80|             42|             39|1.7515527950310559|
# |     12|   148455|Mohamed Salah|    20000000|2016-01-04|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         47|          22|           11|           14|1.6382978723404256|[CL, FAC, CIT, EL...|      5|          47|   15|          3351|        0|           3|      20000000|     12|              159|            75|             43|             41|1.6855345911949686|
# |    631|   148455|Mohamed Salah|    20000000|2016-01-04|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         47|          22|           11|           14|1.6382978723404256|[CL, FAC, CIT, EL...|      5|          47|   15|          3351|        0|           3|      20000000|    631|              159|            75|             43|             41|1.6855345911949686|
# |    430|   148455|Mohamed Salah|    20000000|2016-01-04|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         47|          22|           11|           14|1.6382978723404256|[CL, FAC, CIT, EL...|      5|          47|   15|          3351|        0|           3|      20000000|    430|              159|            75|             43|             41|1.6855345911949686|
# |     12|   148455|Mohamed Salah|    23000000|2016-04-01|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         49|          24|           11|           14|1.6938775510204083|  [CL, CIT, EL, IT1]|      6|          49|   15|          3799|        0|           3|      20000000|     12|              103|            49|             24|             30|1.6601941747572815|
# |    430|   148455|Mohamed Salah|    23000000|2016-04-01|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         49|          24|           11|           14|1.6938775510204083|  [CL, CIT, EL, IT1]|      6|          49|   15|          3799|        0|           3|      20000000|    430|              103|            49|             24|             30|1.6601941747572815|
# |     12|   148455|Mohamed Salah|    27000000|2016-07-15|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         42|          23|           12|            7|1.9285714285714286|      [CL, CIT, IT1]|      6|          42|   15|          3402|        0|           3|      23000000|     12|               47|            24|             14|              9|1.8297872340425532|
# |     12|   148455|Mohamed Salah|    30000000|2017-01-02|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         44|          26|           10|            8|               2.0|  [CL, EL, IT1, CLQ]|     10|          44|   18|          3549|        0|           3|      27000000|     12|               49|            29|             12|              8| 2.020408163265306|
# |     12|   148455|Mohamed Salah|    35000000|2017-06-08|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         41|          27|            5|            9| 2.097560975609756| [CIT, EL, IT1, CLQ]|     12|          41|   19|          3186|        0|           2|      30000000|     12|               54|            36|              7|             11|2.1296296296296298|
# |     31|   148455|Mohamed Salah|    40000000|2017-10-23|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         46|          29|            9|            8|2.0869565217391304|[CL, CIT, EL, IT1...|     13|          46|   24|          3565|        0|           2|      35000000|     31|               98|            60|             20|             18|2.0408163265306123|
# |     12|   148455|Mohamed Salah|    40000000|2017-10-23|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         46|          29|            9|            8|2.0869565217391304|[CL, CIT, EL, IT1...|     13|          46|   24|          3565|        0|           2|      35000000|     12|               98|            60|             20|             18|2.0408163265306123|
# |     31|   148455|Mohamed Salah|    80000000|2018-01-02|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         49|          31|           12|            6| 2.142857142857143|[CL, CIT, EL, IT1...|     14|          49|   33|          3831|        0|           0|      40000000|     31|              105|            63|             24|             18|2.0285714285714285|
# |     12|   148455|Mohamed Salah|    80000000|2018-01-02|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         49|          31|           12|            6| 2.142857142857143|[CL, CIT, EL, IT1...|     14|          49|   33|          3831|        0|           0|      40000000|     12|              105|            63|             24|             18|2.0285714285714285|
# |     31|   148455|Mohamed Salah|   150000000|2018-05-28|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         56|          33|           15|            8|2.0357142857142856|[CL, FAC, IT1, CL...|     16|          56|   46|          4435|        0|           1|      80000000|     31|              107|            61|             26|             20|1.9532710280373833|
# |     12|   148455|Mohamed Salah|   150000000|2018-05-28|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         56|          33|           15|            8|2.0357142857142856|[CL, FAC, IT1, CL...|     16|          56|   46|          4435|        0|           1|      80000000|     12|              107|            61|             26|             20|1.9532710280373833|
# |     31|   148455|Mohamed Salah|   150000000|2018-12-19|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         54|          35|           10|            9|2.1296296296296298|      [CL, FAC, GB1]|     16|          54|   40|          4413|        0|           2|     150000000|     31|               52|            34|              9|              9|2.1346153846153846|
# |     31|   148455|Mohamed Salah|   150000000|2019-06-13|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         51|          37|            8|            6|2.3333333333333335|      [CL, FAC, GB1]|     12|          51|   27|          4339|        0|           2|     150000000|     31|               52|            38|              8|              6|2.3461538461538463|
# |     31|   148455|Mohamed Salah|   150000000|2019-12-10|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         53|          42|            6|            5| 2.490566037735849|[CL, GBCS, FAC, G...|     14|          53|   30|          4556|        0|           2|     150000000|     31|               55|            43|              7|              5|2.4727272727272727|
# |     31|   148455|Mohamed Salah|   120000000|2020-04-08|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         50|          41|            2|            7|               2.5|[CL, GBCS, FAC, G...|     12|          50|   29|          4306|        0|           3|     150000000|     31|               55|            45|              3|              7|2.5090909090909093|
# |     31|   148455|Mohamed Salah|   120000000|2020-10-13|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         43|          32|            3|            8| 2.302325581395349|[CL, GBCS, FAC, G...|     10|          43|   24|          3592|        0|           2|     120000000|     31|               47|            34|              5|              8| 2.276595744680851|
# |     31|   148455|Mohamed Salah|   110000000|2021-03-18|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         50|          25|            9|           16|              1.68|[CL, GBCS, FAC, GB1]|      8|          50|   29|          4059|        0|           0|     120000000|     31|               49|            25|             10|             14|1.7346938775510203|
# |     31|   148455|Mohamed Salah|   100000000|2021-06-08|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         57|          31|           12|           14|1.8421052631578947|[CL, GBCS, FAC, GB1]|     10|          57|   33|          4665|        0|           0|     110000000|     31|               59|            32|             13|             14| 1.847457627118644|
# |     31|   148455|Mohamed Salah|   100000000|2021-12-23|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         58|          35|           13|           10|2.0344827586206895|      [CL, FAC, GB1]|     14|          58|   41|          4910|        0|           1|     100000000|     31|               52|            31|             11|             10|               2.0|
# |     31|   148455|Mohamed Salah|    90000000|2022-06-15|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         49|          36|            9|            4|2.3877551020408165|      [CL, FAC, GB1]|     16|          49|   30|          3823|        0|           1|     100000000|     31|               56|            43|              9|              4|2.4642857142857144|
# |     31|   148455|Mohamed Salah|    80000000|2022-11-03|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         55|          37|            9|            9|2.1818181818181817|[CL, GBCS, FAC, GB1]|     14|          55|   27|          4277|        0|           0|      90000000|     31|               62|            44|              9|              9| 2.274193548387097|
# |     31|   148455|Mohamed Salah|    70000000|2023-03-16|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         58|          33|           10|           15|1.8793103448275863|[CL, CGB, GBCS, F...|     16|          58|   26|          4578|        0|           1|      80000000|     31|               58|            34|             10|             14|1.9310344827586208|
# +-------+---------+-------------+------------+----------+---------------+------+-----------+----------+--------+------------+-----------+------------+-------------+-------------+------------------+--------------------+-------+------------+-----+--------------+---------+------------+--------------+-------+-----------------+--------------+---------------+---------------+------------------+

# %%
df.filter(df.player_id == 148455).show()
# Out:
# +-------+---------+-------------+------------+----------+---------------+------+-----------+----------+--------+------------+-----------+------------+-------------+-------------+------------------+--------------------+-------+------------+-----+--------------+---------+------------+--------------+-------+-----------------+--------------+---------------+---------------+------------------+
# |club_id|player_id|         name|market_value|    date_v|current_club_id|height|citizenship|date_birth|position|sub_position|appearances|games_won_pl|games_draw_pl|games_lost_pl|   winning_rate_pl|      competition_id|assists|appearances2|goals|minutes_played|red_cards|yellow_cards|last_valuation|club_id|games_played_club|games_won_club|games_draw_club|games_lost_club| winning_rate_club|
# +-------+---------+-------------+------------+----------+---------------+------+-----------+----------+--------+------------+-----------+------------+-------------+-------------+------------------+--------------------+-------+------------+-----+--------------+---------+------------+--------------+-------+-----------------+--------------+---------------+---------------+------------------+
# |    430|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|    430|              102|            55|             24|             23|1.8529411764705883|
# |    631|   148455|Mohamed Salah|    10000000|2015-02-12|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|          7|           5|            0|            2| 2.142857142857143| [CL, FAC, IT1, GB1]|      1|           7|    0|           202|        0|           0|          null|    631|              102|            55|             24|             23|1.8529411764705883|
# |    430|   148455|Mohamed Salah|    12000000|2015-03-20|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         16|          10|            3|            3|            2.0625|[CL, FAC, CIT, EL...|      3|          16|    6|           879|        0|           1|      10000000|    430|              102|            56|             27|             19| 1.911764705882353|
# |    631|   148455|Mohamed Salah|    12000000|2015-03-20|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         16|          10|            3|            3|            2.0625|[CL, FAC, CIT, EL...|      3|          16|    6|           879|        0|           1|      10000000|    631|              102|            56|             27|             19| 1.911764705882353|
# |    430|   148455|Mohamed Salah|    18000000|2015-07-01|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         32|          17|            5|           10|              1.75|[CL, FAC, CIT, EL...|      5|          32|    9|          1970|        0|           1|      12000000|    430|              104|            59|             27|             18|1.9615384615384615|
# |    631|   148455|Mohamed Salah|    18000000|2015-07-01|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         32|          17|            5|           10|              1.75|[CL, FAC, CIT, EL...|      5|          32|    9|          1970|        0|           1|      12000000|    631|              104|            59|             27|             18|1.9615384615384615|
# |     12|   148455|Mohamed Salah|    20000000|2015-11-05|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         43|          21|            9|           13|1.6744186046511629|[CL, FAC, CIT, EL...|      5|          43|   15|          3055|        0|           3|      18000000|     12|              161|            80|             42|             39|1.7515527950310559|
# |    430|   148455|Mohamed Salah|    20000000|2015-11-05|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         43|          21|            9|           13|1.6744186046511629|[CL, FAC, CIT, EL...|      5|          43|   15|          3055|        0|           3|      18000000|    430|              161|            80|             42|             39|1.7515527950310559|
# |    631|   148455|Mohamed Salah|    20000000|2015-11-05|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         43|          21|            9|           13|1.6744186046511629|[CL, FAC, CIT, EL...|      5|          43|   15|          3055|        0|           3|      18000000|    631|              161|            80|             42|             39|1.7515527950310559|
# |     12|   148455|Mohamed Salah|    20000000|2016-01-04|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         47|          22|           11|           14|1.6382978723404256|[CL, FAC, CIT, EL...|      5|          47|   15|          3351|        0|           3|      20000000|     12|              159|            75|             43|             41|1.6855345911949686|
# |    430|   148455|Mohamed Salah|    20000000|2016-01-04|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         47|          22|           11|           14|1.6382978723404256|[CL, FAC, CIT, EL...|      5|          47|   15|          3351|        0|           3|      20000000|    430|              159|            75|             43|             41|1.6855345911949686|
# |    631|   148455|Mohamed Salah|    20000000|2016-01-04|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         47|          22|           11|           14|1.6382978723404256|[CL, FAC, CIT, EL...|      5|          47|   15|          3351|        0|           3|      20000000|    631|              159|            75|             43|             41|1.6855345911949686|
# |     12|   148455|Mohamed Salah|    23000000|2016-04-01|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         49|          24|           11|           14|1.6938775510204083|  [CL, CIT, EL, IT1]|      6|          49|   15|          3799|        0|           3|      20000000|     12|              103|            49|             24|             30|1.6601941747572815|
# |    430|   148455|Mohamed Salah|    23000000|2016-04-01|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         49|          24|           11|           14|1.6938775510204083|  [CL, CIT, EL, IT1]|      6|          49|   15|          3799|        0|           3|      20000000|    430|              103|            49|             24|             30|1.6601941747572815|
# |     12|   148455|Mohamed Salah|    27000000|2016-07-15|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         42|          23|           12|            7|1.9285714285714286|      [CL, CIT, IT1]|      6|          42|   15|          3402|        0|           3|      23000000|     12|               47|            24|             14|              9|1.8297872340425532|
# |     12|   148455|Mohamed Salah|    30000000|2017-01-02|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         44|          26|           10|            8|               2.0|  [CL, EL, IT1, CLQ]|     10|          44|   18|          3549|        0|           3|      27000000|     12|               49|            29|             12|              8| 2.020408163265306|
# |     12|   148455|Mohamed Salah|    35000000|2017-06-08|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         41|          27|            5|            9| 2.097560975609756| [CIT, EL, IT1, CLQ]|     12|          41|   19|          3186|        0|           2|      30000000|     12|               54|            36|              7|             11|2.1296296296296298|
# |     12|   148455|Mohamed Salah|    40000000|2017-10-23|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         46|          29|            9|            8|2.0869565217391304|[CL, CIT, EL, IT1...|     13|          46|   24|          3565|        0|           2|      35000000|     12|               98|            60|             20|             18|2.0408163265306123|
# |     31|   148455|Mohamed Salah|    40000000|2017-10-23|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         46|          29|            9|            8|2.0869565217391304|[CL, CIT, EL, IT1...|     13|          46|   24|          3565|        0|           2|      35000000|     31|               98|            60|             20|             18|2.0408163265306123|
# |     12|   148455|Mohamed Salah|    80000000|2018-01-02|             31|   175|      Egypt|1992-06-15|  Attack|Right Winger|         49|          31|           12|            6| 2.142857142857143|[CL, CIT, EL, IT1...|     14|          49|   33|          3831|        0|           0|      40000000|     12|              105|            63|             24|             18|2.0285714285714285|
# +-------+---------+-------------+------------+----------+---------------+------+-----------+----------+--------+------------+-----------+------------+-------------+-------------+------------------+--------------------+-------+------------+-----+--------------+---------+------------+--------------+-------+-----------------+--------------+---------------+---------------+------------------+
# only showing top 20 rows

# %%
#arrange columns, delete and rename some columns, aggregate club_id
df = df.groupBy(
    "player_id", "date_v", "market_value", "name", "date_birth", "current_club_id", "height", "citizenship", "position", "sub_position", col("competition_id").alias("competitions_id"),
    "assists", "goals", "minutes_played", "red_cards", "yellow_cards", "last_valuation", "appearances", "games_won_pl", "games_draw_pl", "games_lost_pl", "winning_rate_pl",
    "games_played_club", "games_won_club", "games_draw_club", "games_lost_club", "winning_rate_club") \
    .agg(collect_set("club_id").alias("clubs_id"))

# %%
# add column age that is equal to date_v - date_birth cifra intera
df = df.withColumn("age", floor(datediff(df.date_v, df.date_birth)/365))

# %%
# take only the first digit after the comma of winning_rate_pl and winning_rate_club
df = df.withColumn("winning_rate_pl", round(df.winning_rate_pl, 1))
df = df.withColumn("winning_rate_club", round(df.winning_rate_club, 1))

# %%
df = df.select("player_id", "date_v", "market_value", "name", "date_birth", "age", "current_club_id", "height", "citizenship", "position", "sub_position", "competitions_id", "clubs_id",
    "assists", "goals", "minutes_played", "red_cards", "yellow_cards", "last_valuation", "appearances", "games_won_pl", "games_draw_pl", "games_lost_pl", "winning_rate_pl",
    "games_played_club", "games_won_club", "games_draw_club", "games_lost_club", "winning_rate_club")

# %%
df.filter(df.player_id == 148455).show(50)
# Out:
# +---------+----------+------------+-------------+----------+---+---------------+------+-----------+--------+------------+--------------------+--------------+-------+-----+--------------+---------+------------+--------------+-----------+------------+-------------+-------------+---------------+-----------------+--------------+---------------+---------------+-----------------+
# |player_id|    date_v|market_value|         name|date_birth|age|current_club_id|height|citizenship|position|sub_position|     competitions_id|      clubs_id|assists|goals|minutes_played|red_cards|yellow_cards|last_valuation|appearances|games_won_pl|games_draw_pl|games_lost_pl|winning_rate_pl|games_played_club|games_won_club|games_draw_club|games_lost_club|winning_rate_club|
# +---------+----------+------------+-------------+----------+---+---------------+------+-----------+--------+------------+--------------------+--------------+-------+-----+--------------+---------+------------+--------------+-----------+------------+-------------+-------------+---------------+-----------------+--------------+---------------+---------------+-----------------+
# |   148455|2015-02-12|    10000000|Mohamed Salah|1992-06-15| 22|             31|   175|      Egypt|  Attack|Right Winger| [CL, FAC, IT1, GB1]|    [430, 631]|      1|    0|           202|        0|           0|          null|          7|           5|            0|            2|            2.1|              102|            55|             24|             23|              1.9|
# |   148455|2015-03-20|    12000000|Mohamed Salah|1992-06-15| 22|             31|   175|      Egypt|  Attack|Right Winger|[CL, FAC, CIT, EL...|    [430, 631]|      3|    6|           879|        0|           1|      10000000|         16|          10|            3|            3|            2.1|              102|            56|             27|             19|              1.9|
# |   148455|2015-07-01|    18000000|Mohamed Salah|1992-06-15| 23|             31|   175|      Egypt|  Attack|Right Winger|[CL, FAC, CIT, EL...|    [430, 631]|      5|    9|          1970|        0|           1|      12000000|         32|          17|            5|           10|            1.8|              104|            59|             27|             18|              2.0|
# |   148455|2015-11-05|    20000000|Mohamed Salah|1992-06-15| 23|             31|   175|      Egypt|  Attack|Right Winger|[CL, FAC, CIT, EL...|[12, 430, 631]|      5|   15|          3055|        0|           3|      18000000|         43|          21|            9|           13|            1.7|              161|            80|             42|             39|              1.8|
# |   148455|2016-01-04|    20000000|Mohamed Salah|1992-06-15| 23|             31|   175|      Egypt|  Attack|Right Winger|[CL, FAC, CIT, EL...|[12, 430, 631]|      5|   15|          3351|        0|           3|      20000000|         47|          22|           11|           14|            1.6|              159|            75|             43|             41|              1.7|
# |   148455|2016-04-01|    23000000|Mohamed Salah|1992-06-15| 23|             31|   175|      Egypt|  Attack|Right Winger|  [CL, CIT, EL, IT1]|     [12, 430]|      6|   15|          3799|        0|           3|      20000000|         49|          24|           11|           14|            1.7|              103|            49|             24|             30|              1.7|
# |   148455|2016-07-15|    27000000|Mohamed Salah|1992-06-15| 24|             31|   175|      Egypt|  Attack|Right Winger|      [CL, CIT, IT1]|          [12]|      6|   15|          3402|        0|           3|      23000000|         42|          23|           12|            7|            1.9|               47|            24|             14|              9|              1.8|
# |   148455|2017-01-02|    30000000|Mohamed Salah|1992-06-15| 24|             31|   175|      Egypt|  Attack|Right Winger|  [CL, EL, IT1, CLQ]|          [12]|     10|   18|          3549|        0|           3|      27000000|         44|          26|           10|            8|            2.0|               49|            29|             12|              8|              2.0|
# |   148455|2017-06-08|    35000000|Mohamed Salah|1992-06-15| 24|             31|   175|      Egypt|  Attack|Right Winger| [CIT, EL, IT1, CLQ]|          [12]|     12|   19|          3186|        0|           2|      30000000|         41|          27|            5|            9|            2.1|               54|            36|              7|             11|              2.1|
# |   148455|2017-10-23|    40000000|Mohamed Salah|1992-06-15| 25|             31|   175|      Egypt|  Attack|Right Winger|[CL, CIT, EL, IT1...|      [12, 31]|     13|   24|          3565|        0|           2|      35000000|         46|          29|            9|            8|            2.1|               98|            60|             20|             18|              2.0|
# |   148455|2018-01-02|    80000000|Mohamed Salah|1992-06-15| 25|             31|   175|      Egypt|  Attack|Right Winger|[CL, CIT, EL, IT1...|      [12, 31]|     14|   33|          3831|        0|           0|      40000000|         49|          31|           12|            6|            2.1|              105|            63|             24|             18|              2.0|
# |   148455|2018-05-28|   150000000|Mohamed Salah|1992-06-15| 25|             31|   175|      Egypt|  Attack|Right Winger|[CL, FAC, IT1, CL...|      [12, 31]|     16|   46|          4435|        0|           1|      80000000|         56|          33|           15|            8|            2.0|              107|            61|             26|             20|              2.0|
# |   148455|2018-12-19|   150000000|Mohamed Salah|1992-06-15| 26|             31|   175|      Egypt|  Attack|Right Winger|      [CL, FAC, GB1]|          [31]|     16|   40|          4413|        0|           2|     150000000|         54|          35|           10|            9|            2.1|               52|            34|              9|              9|              2.1|
# |   148455|2019-06-13|   150000000|Mohamed Salah|1992-06-15| 27|             31|   175|      Egypt|  Attack|Right Winger|      [CL, FAC, GB1]|          [31]|     12|   27|          4339|        0|           2|     150000000|         51|          37|            8|            6|            2.3|               52|            38|              8|              6|              2.3|
# |   148455|2019-12-10|   150000000|Mohamed Salah|1992-06-15| 27|             31|   175|      Egypt|  Attack|Right Winger|[CL, GBCS, FAC, G...|          [31]|     14|   30|          4556|        0|           2|     150000000|         53|          42|            6|            5|            2.5|               55|            43|              7|              5|              2.5|
# |   148455|2020-04-08|   120000000|Mohamed Salah|1992-06-15| 27|             31|   175|      Egypt|  Attack|Right Winger|[CL, GBCS, FAC, G...|          [31]|     12|   29|          4306|        0|           3|     150000000|         50|          41|            2|            7|            2.5|               55|            45|              3|              7|              2.5|
# |   148455|2020-10-13|   120000000|Mohamed Salah|1992-06-15| 28|             31|   175|      Egypt|  Attack|Right Winger|[CL, GBCS, FAC, G...|          [31]|     10|   24|          3592|        0|           2|     120000000|         43|          32|            3|            8|            2.3|               47|            34|              5|              8|              2.3|
# |   148455|2021-03-18|   110000000|Mohamed Salah|1992-06-15| 28|             31|   175|      Egypt|  Attack|Right Winger|[CL, GBCS, FAC, GB1]|          [31]|      8|   29|          4059|        0|           0|     120000000|         50|          25|            9|           16|            1.7|               49|            25|             10|             14|              1.7|
# |   148455|2021-06-08|   100000000|Mohamed Salah|1992-06-15| 29|             31|   175|      Egypt|  Attack|Right Winger|[CL, GBCS, FAC, GB1]|          [31]|     10|   33|          4665|        0|           0|     110000000|         57|          31|           12|           14|            1.8|               59|            32|             13|             14|              1.8|
# |   148455|2021-12-23|   100000000|Mohamed Salah|1992-06-15| 29|             31|   175|      Egypt|  Attack|Right Winger|      [CL, FAC, GB1]|          [31]|     14|   41|          4910|        0|           1|     100000000|         58|          35|           13|           10|            2.0|               52|            31|             11|             10|              2.0|
# |   148455|2022-06-15|    90000000|Mohamed Salah|1992-06-15| 30|             31|   175|      Egypt|  Attack|Right Winger|      [CL, FAC, GB1]|          [31]|     16|   30|          3823|        0|           1|     100000000|         49|          36|            9|            4|            2.4|               56|            43|              9|              4|              2.5|
# |   148455|2022-11-03|    80000000|Mohamed Salah|1992-06-15| 30|             31|   175|      Egypt|  Attack|Right Winger|[CL, GBCS, FAC, GB1]|          [31]|     14|   27|          4277|        0|           0|      90000000|         55|          37|            9|            9|            2.2|               62|            44|              9|              9|              2.3|
# |   148455|2023-03-16|    70000000|Mohamed Salah|1992-06-15| 30|             31|   175|      Egypt|  Attack|Right Winger|[CL, CGB, GBCS, F...|          [31]|     16|   26|          4578|        0|           1|      80000000|         58|          33|           10|           15|            1.9|               58|            34|             10|             14|              1.9|
# +---------+----------+------------+-------------+----------+---+---------------+------+-----------+--------+------------+--------------------+--------------+-------+-----+--------------+---------+------------+--------------+-----------+------------+-------------+-------------+---------------+-----------------+--------------+---------------+---------------+-----------------+

# %%
# TODO possiamo pensare di eliminare games_played_club, games_won_club, games_draw_club, games_lost_club e lasciare solo winning_rate_club

# %%
df = df.drop("competitions_id")
df = df.drop("clubs_id")
df.write.mode("overwrite").csv("data/data.csv")
